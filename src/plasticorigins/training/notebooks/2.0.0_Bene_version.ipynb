# %%
# %cd /Users/packo/Documents/Projets/surfrider/yolov5_train_test/
# Replace the XX in file paths.
# Out:
# c:\Users\packo\Documents\Projets\surfrider\yolov5_train_test

# %%
pip install -r requirements.txt
# Out:
# Obtaining file:///C:/Users/packo/Documents/Projets/surfrider/yolov5_train_test (from -r requirements.txt (line 2))
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# Collecting cocotools
#   Using cached cocotools-0.2.0.1-py3-none-any.whl (14 kB)
# Requirement already satisfied: matplotlib in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from -r requirements.txt (line 4)) (3.5.1)
# Requirement already satisfied: notebook in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from -r requirements.txt (line 5)) (6.4.11)
# Requirement already satisfied: numpy in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from -r requirements.txt (line 6)) (1.22.3)
# Requirement already satisfied: opencv-python in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from -r requirements.txt (line 7)) (4.5.5.62)
# Requirement already satisfied: pandas in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from -r requirements.txt (line 8)) (1.4.3)
# Requirement already satisfied: Pillow in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from -r requirements.txt (line 9)) (9.1.0)
# Requirement already satisfied: pip in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from -r requirements.txt (line 10)) (21.2.2)
# Collecting pycocotools
#   Using cached pycocotools-2.0.4.tar.gz (106 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'Note: you may need to restart the kernel to use updated packages.
#   ERROR: Command errored out with exit status 1:
#    command: 'c:\Users\packo\anaconda3\envs\surfenv\python.exe' 'c:\Users\packo\anaconda3\envs\surfenv\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py' build_wheel 'C:\Users\packo\AppData\Local\Temp\tmp48d4cnc4'
#        cwd: C:\Users\packo\AppData\Local\Temp\pip-install-q00wa0l2\pycocotools_8cc52865fef6410b886e5dcfe1d1195e
#   Complete output (14 lines):
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-cpython-38
#   creating build\lib.win-amd64-cpython-38\pycocotools
#   copying pycocotools\coco.py -> build\lib.win-amd64-cpython-38\pycocotools
#   copying pycocotools\cocoeval.py -> build\lib.win-amd64-cpython-38\pycocotools
#   copying pycocotools\mask.py -> build\lib.win-amd64-cpython-38\pycocotools
#   copying pycocotools\__init__.py -> build\lib.win-amd64-cpython-38\pycocotools
#   running build_ext
#   skipping 'pycocotools\_mask.c' Cython extension (up-to-date)
#   building 'pycocotools._mask' extension
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   ----------------------------------------
#   ERROR: Failed building wheel for pycocotools
# ERROR: Could not build wheels for pycocotools which use PEP 517 and cannot be installed directly
# Requirement already satisfied: scikit-learn in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from -r requirements.txt (line 12)) (1.1.1)
# Requirement already satisfied: scipy in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from -r requirements.txt (line 13)) (1.7.3)
# Collecting seaborn
#   Using cached seaborn-0.11.2-py3-none-any.whl (292 kB)
# Requirement already satisfied: sklearn in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from -r requirements.txt (line 15)) (0.0)
# Requirement already satisfied: torch in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from -r requirements.txt (line 16)) (1.11.0)
# Requirement already satisfied: torchvision in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from -r requirements.txt (line 17)) (0.12.0)
# Collecting wandb
#   Using cached wandb-0.12.19-py2.py3-none-any.whl (1.8 MB)
# Requirement already satisfied: shapely in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from -r requirements.txt (line 19)) (1.8.1.post1)
# Collecting tensorboard
#   Using cached tensorboard-2.9.1-py3-none-any.whl (5.8 MB)
# Requirement already satisfied: click in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from -r requirements.txt (line 23)) (8.1.2)
# Collecting Sphinx
#   Using cached Sphinx-5.0.2-py3-none-any.whl (3.1 MB)
# Requirement already satisfied: coverage in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from -r requirements.txt (line 25)) (6.3.2)
# Collecting awscli
#   Using cached awscli-1.25.17-py3-none-any.whl (3.9 MB)
# Requirement already satisfied: flake8 in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from -r requirements.txt (line 27)) (4.0.1)
# Collecting python-dotenv>=0.5.1
#   Using cached python_dotenv-0.20.0-py3-none-any.whl (17 kB)
# Collecting loguru
#   Using cached loguru-0.6.0-py3-none-any.whl (58 kB)
# Requirement already satisfied: setuptools in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from cocotools->-r requirements.txt (line 3)) (61.2.0)
# Collecting easydict
#   Using cached easydict-1.9-py3-none-any.whl
# Collecting typer[all]
#   Using cached typer-0.4.1-py3-none-any.whl (27 kB)
# Requirement already satisfied: tqdm in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from cocotools->-r requirements.txt (line 3)) (4.62.3)
# Collecting imagesize
#   Using cached imagesize-1.3.0-py2.py3-none-any.whl (5.2 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from matplotlib->-r requirements.txt (line 4)) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from matplotlib->-r requirements.txt (line 4)) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from matplotlib->-r requirements.txt (line 4)) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from matplotlib->-r requirements.txt (line 4)) (3.0.8)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from matplotlib->-r requirements.txt (line 4)) (1.4.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from matplotlib->-r requirements.txt (line 4)) (4.32.0)
# Requirement already satisfied: ipykernel in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from notebook->-r requirements.txt (line 5)) (6.9.1)
# Requirement already satisfied: tornado>=6.1 in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from notebook->-r requirements.txt (line 5)) (6.1)
# Requirement already satisfied: nbconvert>=5 in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from notebook->-r requirements.txt (line 5)) (6.4.4)
# Requirement already satisfied: argon2-cffi in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from notebook->-r requirements.txt (line 5)) (21.3.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from notebook->-r requirements.txt (line 5)) (1.8.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from notebook->-r requirements.txt (line 5)) (4.10.0)
# Requirement already satisfied: pyzmq>=17 in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from notebook->-r requirements.txt (line 5)) (22.3.0)
# Requirement already satisfied: traitlets>=4.2.1 in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from notebook->-r requirements.txt (line 5)) (5.1.1)
# Requirement already satisfied: jinja2 in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from notebook->-r requirements.txt (line 5)) (3.1.1)
# Requirement already satisfied: nbformat in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from notebook->-r requirements.txt (line 5)) (5.3.0)
# Requirement already satisfied: jupyter-client>=5.3.4 in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from notebook->-r requirements.txt (line 5)) (7.2.2)
# Requirement already satisfied: nest-asyncio>=1.5 in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from notebook->-r requirements.txt (line 5)) (1.5.5)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from notebook->-r requirements.txt (line 5)) (0.13.1)
# Requirement already satisfied: prometheus-client in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from notebook->-r requirements.txt (line 5)) (0.13.1)
# Requirement already satisfied: ipython-genutils in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from notebook->-r requirements.txt (line 5)) (0.2.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from pandas->-r requirements.txt (line 8)) (2022.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from scikit-learn->-r requirements.txt (line 12)) (3.1.0)
# Requirement already satisfied: joblib>=1.0.0 in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from scikit-learn->-r requirements.txt (line 12)) (1.1.0)
# Requirement already satisfied: typing-extensions in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from torch->-r requirements.txt (line 16)) (4.2.0)
# Requirement already satisfied: requests in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from torchvision->-r requirements.txt (line 17)) (2.27.1)
# Collecting protobuf<4.0dev,>=3.12.0
#   Using cached protobuf-3.20.1-cp38-cp38-win_amd64.whl (904 kB)
# Collecting psutil>=5.0.0
#   Using cached psutil-5.9.1-cp38-cp38-win_amd64.whl (246 kB)
# Collecting pathtools
#   Using cached pathtools-0.1.2-py3-none-any.whl
# Collecting setproctitle
#   Using cached setproctitle-1.2.3-cp38-cp38-win_amd64.whl (10 kB)
# Collecting GitPython>=1.0.0
#   Using cached GitPython-3.1.27-py3-none-any.whl (181 kB)
# Requirement already satisfied: six>=1.13.0 in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from wandb->-r requirements.txt (line 18)) (1.16.0)
# Collecting sentry-sdk>=1.0.0
#   Using cached sentry_sdk-1.6.0-py2.py3-none-any.whl (145 kB)
# Requirement already satisfied: PyYAML in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from wandb->-r requirements.txt (line 18)) (6.0)
# Collecting docker-pycreds>=0.4.0
#   Using cached docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Collecting promise<3,>=2.0
#   Using cached promise-2.3-py3-none-any.whl
# Collecting shortuuid>=0.5.0
#   Using cached shortuuid-1.0.9-py3-none-any.whl (9.4 kB)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Using cached google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from tensorboard->-r requirements.txt (line 20)) (2.0.3)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Using cached tensorboard_data_server-0.6.1-py3-none-any.whl (2.4 kB)
# Collecting grpcio>=1.24.3
#   Using cached grpcio-1.47.0-cp38-cp38-win_amd64.whl (3.6 MB)
# Collecting absl-py>=0.4
#   Using cached absl_py-1.1.0-py3-none-any.whl (123 kB)
# Collecting protobuf<4.0dev,>=3.12.0
#   Using cached protobuf-3.19.4-cp38-cp38-win_amd64.whl (895 kB)
# Collecting google-auth<3,>=1.6.3
#   Using cached google_auth-2.8.0-py2.py3-none-any.whl (164 kB)
# Requirement already satisfied: wheel>=0.26 in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from tensorboard->-r requirements.txt (line 20)) (0.37.1)
# Collecting tensorboard-plugin-wit>=1.6.0
#   Using cached tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
# Collecting markdown>=2.6.8
#   Using cached Markdown-3.3.7-py3-none-any.whl (97 kB)
# Requirement already satisfied: colorama in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from click->-r requirements.txt (line 23)) (0.4.4)
# Collecting sphinxcontrib-serializinghtml>=1.1.5
#   Using cached sphinxcontrib_serializinghtml-1.1.5-py2.py3-none-any.whl (94 kB)
# Collecting importlib-metadata>=4.4
#   Using cached importlib_metadata-4.12.0-py3-none-any.whl (21 kB)
# Collecting sphinxcontrib-htmlhelp>=2.0.0
#   Using cached sphinxcontrib_htmlhelp-2.0.0-py2.py3-none-any.whl (100 kB)
# Collecting snowballstemmer>=1.1
#   Using cached snowballstemmer-2.2.0-py2.py3-none-any.whl (93 kB)
# Collecting sphinxcontrib-qthelp
#   Using cached sphinxcontrib_qthelp-1.0.3-py2.py3-none-any.whl (90 kB)
# Requirement already satisfied: Pygments>=2.0 in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from Sphinx->-r requirements.txt (line 24)) (2.11.2)
# Collecting sphinxcontrib-devhelp
#   Using cached sphinxcontrib_devhelp-1.0.2-py2.py3-none-any.whl (84 kB)
# Collecting babel>=1.3
#   Using cached Babel-2.10.3-py3-none-any.whl (9.5 MB)
# Collecting sphinxcontrib-applehelp
#   Using cached sphinxcontrib_applehelp-1.0.2-py2.py3-none-any.whl (121 kB)
# Collecting alabaster<0.8,>=0.7
#   Using cached alabaster-0.7.12-py2.py3-none-any.whl (14 kB)
# Collecting sphinxcontrib-jsmath
#   Using cached sphinxcontrib_jsmath-1.0.1-py2.py3-none-any.whl (5.1 kB)
# Collecting docutils<0.19,>=0.14
#   Using cached docutils-0.18.1-py2.py3-none-any.whl (570 kB)
# Collecting PyYAML
#   Using cached PyYAML-5.4.1-cp38-cp38-win_amd64.whl (213 kB)
# Collecting botocore==1.27.17
#   Using cached botocore-1.27.17-py3-none-any.whl (8.9 MB)
# Collecting s3transfer<0.7.0,>=0.6.0
#   Using cached s3transfer-0.6.0-py3-none-any.whl (79 kB)
# Collecting rsa<4.8,>=3.1.2
#   Using cached rsa-4.7.2-py3-none-any.whl (34 kB)
# Collecting docutils<0.19,>=0.14
#   Using cached docutils-0.16-py2.py3-none-any.whl (548 kB)
# Collecting jmespath<2.0.0,>=0.7.1
#   Using cached jmespath-1.0.1-py3-none-any.whl (20 kB)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from botocore==1.27.17->awscli->-r requirements.txt (line 26)) (1.26.9)
# Requirement already satisfied: mccabe<0.7.0,>=0.6.0 in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from flake8->-r requirements.txt (line 27)) (0.6.1)
# Requirement already satisfied: pycodestyle<2.9.0,>=2.8.0 in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from flake8->-r requirements.txt (line 27)) (2.8.0)
# Requirement already satisfied: pyflakes<2.5.0,>=2.4.0 in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from flake8->-r requirements.txt (line 27)) (2.4.0)
# Collecting gitdb<5,>=4.0.1
#   Using cached gitdb-4.0.9-py3-none-any.whl (63 kB)
# Collecting smmap<6,>=3.0.1
#   Using cached smmap-5.0.0-py3-none-any.whl (24 kB)
# Collecting pyasn1-modules>=0.2.1
#   Using cached pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Collecting cachetools<6.0,>=2.0.0
#   Using cached cachetools-5.2.0-py3-none-any.whl (9.3 kB)
# Collecting requests-oauthlib>=0.7.0
#   Using cached requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: zipp>=0.5 in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from importlib-metadata>=4.4->Sphinx->-r requirements.txt (line 24)) (3.8.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from jinja2->notebook->-r requirements.txt (line 5)) (2.1.1)
# Requirement already satisfied: entrypoints in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from jupyter-client>=5.3.4->notebook->-r requirements.txt (line 5)) (0.4)
# Requirement already satisfied: pywin32>=1.0 in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from jupyter-core>=4.6.1->notebook->-r requirements.txt (line 5)) (302)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from nbconvert>=5->notebook->-r requirements.txt (line 5)) (0.8.4)
# Requirement already satisfied: bleach in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from nbconvert>=5->notebook->-r requirements.txt (line 5)) (4.1.0)
# Requirement already satisfied: testpath in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from nbconvert>=5->notebook->-r requirements.txt (line 5)) (0.5.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from nbconvert>=5->notebook->-r requirements.txt (line 5)) (4.11.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from nbconvert>=5->notebook->-r requirements.txt (line 5)) (0.5.13)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from nbconvert>=5->notebook->-r requirements.txt (line 5)) (1.5.0)
# Requirement already satisfied: jupyterlab-pygments in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from nbconvert>=5->notebook->-r requirements.txt (line 5)) (0.1.2)
# Requirement already satisfied: defusedxml in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from nbconvert>=5->notebook->-r requirements.txt (line 5)) (0.7.1)
# Requirement already satisfied: fastjsonschema in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from nbformat->notebook->-r requirements.txt (line 5)) (2.15.1)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from nbformat->notebook->-r requirements.txt (line 5)) (4.4.0)
# Requirement already satisfied: importlib-resources>=1.4.0 in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from jsonschema>=2.6->nbformat->notebook->-r requirements.txt (line 5)) (5.2.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from jsonschema>=2.6->nbformat->notebook->-r requirements.txt (line 5)) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from jsonschema>=2.6->nbformat->notebook->-r requirements.txt (line 5)) (21.4.0)
# Collecting pyasn1<0.5.0,>=0.4.6
#   Using cached pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from requests->torchvision->-r requirements.txt (line 17)) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from requests->torchvision->-r requirements.txt (line 17)) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from requests->torchvision->-r requirements.txt (line 17)) (2022.5.18.1)
# Collecting oauthlib>=3.0.0
#   Using cached oauthlib-3.2.0-py3-none-any.whl (151 kB)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from terminado>=0.8.3->notebook->-r requirements.txt (line 5)) (2.0.2)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from argon2-cffi->notebook->-r requirements.txt (line 5)) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook->-r requirements.txt (line 5)) (1.15.0)
# Requirement already satisfied: pycparser in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->-r requirements.txt (line 5)) (2.21)
# Requirement already satisfied: soupsieve>1.2 in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from beautifulsoup4->nbconvert>=5->notebook->-r requirements.txt (line 5)) (2.3.1)
# Requirement already satisfied: webencodings in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from bleach->nbconvert>=5->notebook->-r requirements.txt (line 5)) (0.5.1)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from ipykernel->notebook->-r requirements.txt (line 5)) (1.5.1)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from ipykernel->notebook->-r requirements.txt (line 5)) (8.3.0)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from ipykernel->notebook->-r requirements.txt (line 5)) (0.1.2)
# Requirement already satisfied: stack-data in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from ipython>=7.23.1->ipykernel->notebook->-r requirements.txt (line 5)) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from ipython>=7.23.1->ipykernel->notebook->-r requirements.txt (line 5)) (3.0.20)
# Requirement already satisfied: pickleshare in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from ipython>=7.23.1->ipykernel->notebook->-r requirements.txt (line 5)) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from ipython>=7.23.1->ipykernel->notebook->-r requirements.txt (line 5)) (0.18.1)
# Requirement already satisfied: backcall in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from ipython>=7.23.1->ipykernel->notebook->-r requirements.txt (line 5)) (0.2.0)
# Requirement already satisfied: decorator in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from ipython>=7.23.1->ipykernel->notebook->-r requirements.txt (line 5)) (5.1.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->notebook->-r requirements.txt (line 5)) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.23.1->ipykernel->notebook->-r requirements.txt (line 5)) (0.2.5)
# Collecting win32-setctime>=1.0.0
#   Using cached win32_setctime-1.1.0-py3-none-any.whl (3.6 kB)
# Requirement already satisfied: executing in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->notebook->-r requirements.txt (line 5)) (0.8.3)
# Requirement already satisfied: pure-eval in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->notebook->-r requirements.txt (line 5)) (0.2.2)
# Requirement already satisfied: asttokens in c:\users\packo\anaconda3\envs\surfenv\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->notebook->-r requirements.txt (line 5)) (2.0.5)
# Collecting shellingham<2.0.0,>=1.3.0
#   Using cached shellingham-1.4.0-py2.py3-none-any.whl (9.4 kB)
# Building wheels for collected packages: pycocotools
#   Building wheel for pycocotools (PEP 517): started
#   Building wheel for pycocotools (PEP 517): finished with status 'error'
# Failed to build pycocotools

# %%
# !pip3 install "git+https://github.com/philferriere/cocoapi.git#egg=pycocotools&subdirectory=PythonAPI"
# Out:
# Collecting pycocotools
#   Cloning https://github.com/philferriere/cocoapi.git to c:\users\packo\appdata\local\temp\pip-install-6phlkbc7\pycocotools_917b6acf71984f25b5db545bf1d2fe6d
#   Resolved https://github.com/philferriere/cocoapi.git to commit 2929bd2ef6b451054755dfd7ceb09278f935f7ad
# Building wheels for collected packages: pycocotools
#   Building wheel for pycocotools (setup.py): started
#   Building wheel for pycocotools (setup.py): finished with status 'error'
#   Running setup.py clean for pycocotools
# Failed to build pycocotools
# Installing collected packages: pycocotools
#     Running setup.py install for pycocotools: started
#     Running setup.py install for pycocotools: finished with status 'error'
#   Running command git clone -q https://github.com/philferriere/cocoapi.git 'C:\Users\packo\AppData\Local\Temp\pip-install-6phlkbc7\pycocotools_917b6acf71984f25b5db545bf1d2fe6d'
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\packo\anaconda3\envs\surfenv\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\packo\\AppData\\Local\\Temp\\pip-install-6phlkbc7\\pycocotools_917b6acf71984f25b5db545bf1d2fe6d\\PythonAPI\\setup.py'"'"'; __file__='"'"'C:\\Users\\packo\\AppData\\Local\\Temp\\pip-install-6phlkbc7\\pycocotools_917b6acf71984f25b5db545bf1d2fe6d\\PythonAPI\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\packo\AppData\Local\Temp\pip-wheel-4ppqmoob'
#        cwd: C:\Users\packo\AppData\Local\Temp\pip-install-6phlkbc7\pycocotools_917b6acf71984f25b5db545bf1d2fe6d\PythonAPI
#   Complete output (13 lines):
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-3.8
#   creating build\lib.win-amd64-3.8\pycocotools
#   copying pycocotools\coco.py -> build\lib.win-amd64-3.8\pycocotools
#   copying pycocotools\cocoeval.py -> build\lib.win-amd64-3.8\pycocotools
#   copying pycocotools\mask.py -> build\lib.win-amd64-3.8\pycocotools
#   copying pycocotools\__init__.py -> build\lib.win-amd64-3.8\pycocotools
#   running build_ext
#   building 'pycocotools._mask' extension
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   ----------------------------------------
#   ERROR: Failed building wheel for pycocotools
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\packo\anaconda3\envs\surfenv\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\packo\\AppData\\Local\\Temp\\pip-install-6phlkbc7\\pycocotools_917b6acf71984f25b5db545bf1d2fe6d\\PythonAPI\\setup.py'"'"'; __file__='"'"'C:\\Users\\packo\\AppData\\Local\\Temp\\pip-install-6phlkbc7\\pycocotools_917b6acf71984f25b5db545bf1d2fe6d\\PythonAPI\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' clean --all
#        cwd: C:\Users\packo\AppData\Local\Temp\pip-install-6phlkbc7\pycocotools_917b6acf71984f25b5db545bf1d2fe6d
#   Complete output (11 lines):
#   Traceback (most recent call last):
#     File "<string>", line 1, in <module>
#     File "C:\Users\packo\AppData\Local\Temp\pip-install-6phlkbc7\pycocotools_917b6acf71984f25b5db545bf1d2fe6d\PythonAPI\setup.py", line 25, in <module>
#       cythonize(ext_modules)
#     File "C:\Users\packo\anaconda3\envs\surfenv\lib\site-packages\Cython\Build\Dependencies.py", line 970, in cythonize
#       module_list, module_metadata = create_extension_list(
#     File "C:\Users\packo\anaconda3\envs\surfenv\lib\site-packages\Cython\Build\Dependencies.py", line 816, in create_extension_list
#       for file in nonempty(sorted(extended_iglob(filepattern)), "'%s' doesn't match any files" % filepattern):
#     File "C:\Users\packo\anaconda3\envs\surfenv\lib\site-packages\Cython\Build\Dependencies.py", line 114, in nonempty
#       raise ValueError(error_msg)
#   ValueError: 'pycocotools/_mask.pyx' doesn't match any files
#   ----------------------------------------
#   ERROR: Failed cleaning build dir for pycocotools
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\packo\anaconda3\envs\surfenv\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\packo\\AppData\\Local\\Temp\\pip-install-6phlkbc7\\pycocotools_917b6acf71984f25b5db545bf1d2fe6d\\PythonAPI\\setup.py'"'"'; __file__='"'"'C:\\Users\\packo\\AppData\\Local\\Temp\\pip-install-6phlkbc7\\pycocotools_917b6acf71984f25b5db545bf1d2fe6d\\PythonAPI\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\packo\AppData\Local\Temp\pip-record-nqb63yz4\install-record.txt' --single-version-externally-managed --compile --install-headers 'C:\Users\packo\anaconda3\envs\surfenv\Include\pycocotools'
#          cwd: C:\Users\packo\AppData\Local\Temp\pip-install-6phlkbc7\pycocotools_917b6acf71984f25b5db545bf1d2fe6d\PythonAPI
#     Complete output (8 lines):
#     running install
#     C:\Users\packo\anaconda3\envs\surfenv\lib\site-packages\setuptools\command\install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#       warnings.warn(
#     running build
#     running build_py
#     running build_ext
#     building 'pycocotools._mask' extension
#     error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: 'C:\Users\packo\anaconda3\envs\surfenv\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\packo\\AppData\\Local\\Temp\\pip-install-6phlkbc7\\pycocotools_917b6acf71984f25b5db545bf1d2fe6d\\PythonAPI\\setup.py'"'"'; __file__='"'"'C:\\Users\\packo\\AppData\\Local\\Temp\\pip-install-6phlkbc7\\pycocotools_917b6acf71984f25b5db545bf1d2fe6d\\PythonAPI\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\packo\AppData\Local\Temp\pip-record-nqb63yz4\install-record.txt' --single-version-externally-managed --compile --install-headers 'C:\Users\packo\anaconda3\envs\surfenv\Include\pycocotools' Check the logs for full command output.

# %%
import json
import numpy as np
import matplotlib.pyplot as plt
from pycocotools.coco import COCO
import pandas as pd
import random
from PIL import Image, ImageDraw, ImageFont, ExifTags
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib.patches as patches
from matplotlib.pyplot import figure
from shapely.geometry import Polygon
import pylab
pylab.rcParams['figure.figsize'] = (8.0, 10.0)
import cv2
import os
import datetime
import torch
import torchvision
# Out:
# Running cells with 'Python 3.9.12 ('plastic-origins--4rS__3v-py3.9')' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/packo/AppData/Local/pypoetry/Cache/virtualenvs/plastic-origins--4rS__3v-py3.9/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %% [markdown]
# we have that the
# - coco : common objects in context, a way to do object detection using json sstructuure which determines how the labels are annotated
# - pycocotools: helps doig the parsing ...
# - we can also add wanb here if needed.

# %% [markdown]
# ## Load Data
# ### CSV Files from SharePoints (Images/BBOXES)

# %%
cd /Users/XX/Documents/surfrider/surfnet/data/images/annotations

# %%
df_bboxes = pd.read_csv("bounding_boxes_202205231416.csv")
df_images = pd.read_csv("images_for_labelling_202205231708.csv")

# %%
df_images.head()

# %%
print(f'Nb. of bboxes : {len(df_bboxes)}')
print(f'Nb. of images : {len(df_images)}')

# %% [markdown]
# I believe we have that there is the images; with different caracteristics, such as the type of view that there is, the nagle of the pic, the quality and the context - the water source/type
#
# Then there is the bonding box, each one is linked to an image ; and has 4 coordinates which determine sthe box. There is also the class ID : with the type of pollution detected (0) -10

# %% [markdown]
# ### Instances Files

# %%
coco_train  = COCO(annotation_file = 'instances_train.json')
coco_valid  = COCO(annotation_file = 'instances_val.json')
coco_images = COCO(annotation_file = 'instances.json')

coco_images_train = coco_train.dataset['images'][1:]
coco_images_valid = coco_valid.dataset['images'][1:]
coco_images       = coco_images.dataset['images'][1:]

# %% [markdown]
# Here we have that the COCO loads the annotation file and prepare data structure

# %%
print(f'Nb. of train images : {len(coco_images_train)}')
print(f'Nb. of val.  images : {len(coco_images_valid)}')
print(f'Nb. of total images : {len(coco_images)}')

# %%
IMAGES_PATH = "images2label"
images      = os.listdir(IMAGES_PATH)
images_full_path = [os.path.join(IMAGES_PATH, x) for x in os.listdir(IMAGES_PATH)]

print(f'Image Path : {len(images)}')

# %% [markdown]
# ## Data Exploration

# %%
filenames = list(df_images.filename.unique())
len(filenames)
# here we're taking the files that are unique : so got rid of the doubles

# %%
filenames_train = [obj['file_name'] for obj in coco_images_train]
filenames_valid = [obj['file_name'] for obj in coco_images_valid]
print("TRAIN", len(filenames_train), "VALID", len(filenames_valid))
filenames_train_valid = filenames_train + filenames_valid
print("TOTAL", len(filenames_train_valid))

#here we have the total train and validity is of 3921 and then the rest would be the one who 
#are on the csv file but not on the instances
# we have that we divided our images into 2 sets one for training and one for validation

# %% [markdown]
# ### Files included in CSV and Instances

# %%
files_inter = list(set(filenames) & set(filenames_train_valid))
len(files_inter)

# %% [markdown]
# ### Files that are CSV but not instances

# %%
set_difference_f = set(filenames) - set(filenames_train_valid)
list_difference_f = list(set_difference_f)
len(list_difference_f)

# %% [markdown]
# ### Names of the files of the Instances that are not in CSV

# %%
set_difference_i = set(filenames_train_valid) - set(filenames)
list_difference_i = list(set_difference_i)
len(list_difference_i)

# %% [markdown]
# ### GroupBy ID

# %%
cd /Users/XX/ZoRaFa/yolov5_train_test/src/surfnet_train/visualization

# %%
from categories import annotations_cat
annotations_cat(df_bboxes);

# %% [markdown]
# the data is unbalanced - way more of categpry 1 : sheet, tarp, plastic bags and fragment
# - Sheet / tarp / plastic bag / fragment
# - Insulating material
# - Bottle-shaped
# - Can-shaped
# - Drum
# - Other packaging
# - Tire
# - Fishing net / cord
# - Easily namable
# - Unclear

# %% [markdown]
# ### GroupBy Context

# %%
from categories import img_context
img_context(df_images);

# %% [markdown]
# The data is unbalanced : once again much more of the river then others ; small beach

# %% [markdown]
# ### GroupBy View

# %%
from categories import img_view
img_view(df_images);

# %% [markdown]
# ### GroupBy Image quality

# %%
from categories import img_quality
img_quality(df_images);

# %% [markdown]
# ## Data Processing

# %%
cd /Users/XX/ZoRaFa/yolov5_train_test/src/surfnet_train/data

# %%
from data_processing import coco2yolo
from data_processing import get_df_train_val

# %%
# !mkdir ./images
# !mkdir ./labels

# %%
cd /Users/XX/ZoRaFa/yolov5_train_test/src/surfnet_train/models

# %%
import path_existance

# %%
get_df_train_val("/Users/XX/Documents/surfrider/surfnet/data/images/annotations/instances.json", "/Users/XX/Documents/surfrider/surfnet/data/images/annotations/images2label" , df_images)

# %% [markdown]
# ### Get Categories

# %%
annotation_file = "annotations-surfnet/instances_train.json"
coco = COCO(annotation_file)

coco_categories = coco.dataset['categories'][1:]
class_id_to_name_mapping = {}
for c in coco_categories:
    class_id_to_name_mapping[c['id']-1] = c['name']

class_id_to_name_mapping

# %% [markdown]
# ### Creation of 2 DataFrames for future manipulation 5GrouppKFold, KFold, Split)

# %%
data_dir = "images2label"

def get_df_train_val(annotation_file):
    
    coco = COCO(annotation_file) #transform the file 

    old_filenames  = []
    dates          = []
    views          = []
    images_quality = []
    contexts       = []
    all_bboxes     = []
    all_images     = []
    new_filenames  = []
    new_labelnames = []

    img_ids = np.array(coco.getImgIds())
    
    for img_id in img_ids:
        image_infos = coco.loadImgs(ids=[img_id])[0]

        if os.path.exists(os.path.join(data_dir, image_infos['file_name'])):

            date_creation  = df_images.loc[df_images["filename"] == image_infos["file_name"]]["createdon"].values[0]
            view           = df_images.loc[df_images["filename"] == image_infos["file_name"]]["view"].values[0]
            image_quality  = df_images.loc[df_images["filename"] == image_infos["file_name"]]["image_quality"].values[0]
            context        = df_images.loc[df_images["filename"] == image_infos["file_name"]]["context"].values[0]

            date_time_obj = datetime.datetime.strptime(date_creation, '%Y-%m-%d %H:%M:%S')

            old_filenames.append(image_infos["file_name"])
            dates.append(date_time_obj)
            views.append(view)
            images_quality.append(image_quality)
            contexts.append(context)

            image = Image.open(os.path.join(data_dir,image_infos['file_name']))
            try:
                for orientation in ExifTags.TAGS.keys():
                    if ExifTags.TAGS[orientation]=='Orientation':
                        break
                exif = image._getexif()
                if exif is not None:
                    if exif[orientation] == 3:
                        image=image.rotate(180, expand=True)
                    elif exif[orientation] == 6:
                        image=image.rotate(270, expand=True)
                    elif exif[orientation] == 8:
                        image=image.rotate(90, expand=True)

            except (AttributeError, KeyError, IndexError):
                # cases: image don't have getexif
                pass

            image    = np.array(image) #cv2.cvtColor(np.array(image.convert('RGB')),  cv2.COLOR_RGB2BGR)
            ann_ids  = coco.getAnnIds(imgIds=[img_id])
            anns     = coco.loadAnns(ids=ann_ids)
            h, w     = image.shape[:-1]
            target_h = 1080
            ratio    = target_h/h
            target_w = int(ratio*w) 
            image    = cv2.resize(image,(target_w,target_h))
            h, w     = image.shape[:-1]
            yolo_annot = []
            for ann in anns:
                cat = ann['category_id'] - 1
                [bbox_x, bbox_y, bbox_w, bbox_h] = (ratio*np.array(ann['bbox'])).astype(int)
                bbox = np.array([bbox_x, bbox_y, bbox_w, bbox_h])
                yolo_bbox = coco2yolo(bbox, target_h, target_w)
                yolo_str  = str(cat) + " " + " ".join(yolo_bbox.astype(str))
                yolo_annot.append(yolo_str)
            
            basename  = os.path.splitext(image_infos['file_name'])[0]
            file_name = str(image_infos['id']) + "-" + basename

            img_file_name   = os.path.join("./images", file_name) + ".jpg"
            label_file_name = os.path.join("./labels", file_name) + ".txt"
            
            # Save Label
            with open(label_file_name, 'w') as f:
                f.write('\n'.join(yolo_annot))

            img_to_save = Image.fromarray(image)
            # Save image
            img_to_save.save(img_file_name)

            all_bboxes.append(yolo_annot)
            new_filenames.append(img_file_name)
            new_labelnames.append(label_file_name)
            all_images.append(img_to_save)
            
    my_list = list(zip(old_filenames, dates, views, images_quality, contexts, new_filenames, new_labelnames, all_images, all_bboxes))
    my_df   = pd.DataFrame(my_list, columns=['old_path', 'date', 'view', 'quality','context', 'img_name', 'label_name', 'img', 'bboxes'])
    
    return my_df

df_train = get_df_train_val("annotations-surfnet/instances_train.json")
df_valid = get_df_train_val("annotations-surfnet/instances_val.json")

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)

#code to see if using the GPU ; helps for the error cuda but only until 50 epochs

# %% [markdown]
# ### Group DataFRames for future manipulation

# %%
print(len(df_train))
print(len(df_valid))

# %%
frames = [df_train, df_valid]
df_train_valid = pd.concat(frames)

df_train_valid.head()

# %%
d = df_train_valid.iloc[0]["date"]
def get_day(d):
    d = d.date()
    return int("".join(str(d).split("-")))

df_train_valid["day"] = df_train_valid["date"].apply(lambda x: get_day(x))
df_train_valid.head()

# %%
print(len(df_train_valid))

# %% [markdown]
# ### Simple Kfold
# Cross-validation, evaluate the model on data sample
# k : nb of groups the data splits into ;
# - it shuffles the data; splits it into k groups ; one of them becomes the test and the others become the train sets. We fit the model on the training sets
# - we use the mean as a test metric
#
# k is usually 5 or 10

# %%
from sklearn.model_selection import KFold

kf = KFold(n_splits=7)
df_train_valid = df_train_valid.reset_index(drop=True)
df_train_valid['fold'] = -1

for fold, (train_idx, val_idx) in enumerate(kf.split(df_train_valid)):
    df_train_valid.loc[val_idx, 'fold'] = fold

display(df_train_valid.fold.value_counts())

# %%
FOLD = 1

train_files = []
val_files   = []
train_df = df_train_valid.query("fold!=@FOLD")
valid_df = df_train_valid.query("fold==@FOLD")

train_files = list(train_df["img_name"].unique())
val_files   = list(valid_df["img_name"].unique())
len(train_files), len(val_files)

# %%
print("Train", 100 * len(train_files)/(len(train_files)+len(val_files)))
print("Valid", 100 * len(val_files)/(len(train_files)+len(val_files)))

# %%
def plot_image_an_bboxes_yolo(image, annotation_list):
    annotations = np.array(annotation_list)
    w, h = image.size
    
    plotted_image = ImageDraw.Draw(image)

    transformed_annotations = np.copy(annotations)
    transformed_annotations[:,[1,3]] = annotations[:,[1,3]] * w
    transformed_annotations[:,[2,4]] = annotations[:,[2,4]] * h 
    
    transformed_annotations[:,1] = transformed_annotations[:,1] - (transformed_annotations[:,3] / 2)
    transformed_annotations[:,2] = transformed_annotations[:,2] - (transformed_annotations[:,4] / 2)
    transformed_annotations[:,3] = transformed_annotations[:,1] + transformed_annotations[:,3]
    transformed_annotations[:,4] = transformed_annotations[:,2] + transformed_annotations[:,4]
    
    for ann in transformed_annotations:
        obj_cls, x0, y0, x1, y1 = ann
        plotted_image.rectangle(((x0,y0), (x1,y1)), outline="#ff8300", width=5)
        
        plotted_image.text((x0, y0 - 10), class_id_to_name_mapping[(int(obj_cls))])
    
    plt.figure(figsize = (12,10))
    plt.imshow(np.array(image))
    plt.show()

# %%
row        = df_train_valid.iloc[282]
img_name   = os.path.join("images-surfnet/images2label", row["old_path"])
img        = row["img"]
label_list = row["bboxes"]
label_list = [x.split(" ") for x in label_list]
label_list = [[float(y) for y in x ] for x in label_list]

plot_image_an_bboxes_yolo(img, label_list)

# %% [markdown]
# ## Training

# %%
import yaml

cwd = './'

with open(os.path.join( cwd , 'train.txt'), 'w') as f:
    for path in train_files:
        f.write(path+'\n')
            
with open(os.path.join(cwd , 'val.txt'), 'w') as f:
    for path in val_files:
        f.write(path+'\n')

data = dict(
    path  = './../',
    train =  os.path.join( cwd , 'train.txt') ,
    val   =  os.path.join( cwd , 'val.txt' ),
    nc    = 10,
    names = ['Sheet / tarp / plastic bag / fragment', 'Insulating material', 'Bottle-shaped', 'Can-shaped', 'Drum', 'Other packaging', 'Tire', 'Fishing net / cord', 'Easily namable', 'Unclear'],
    )

with open(os.path.join( cwd , 'data.yaml'), 'w') as outfile:
    yaml.dump(data, outfile, default_flow_style=False)

f = open(os.path.join( cwd , 'data.yaml'), 'r')
print('\nyaml:')
print(f.read())

# %%
# !git clone https://github.com/ultralytics/yolov5.git

# %%
# %%writefile yolov5/data/hyps/hyp.scratch.yaml
#
# # YOLOv5 🚀 by Ultralytics, GPL-3.0 license
# # Hyperparameters for COCO training from scratch
# # python train.py --batch 40 --cfg yolov5m.yaml --weights '' --data coco.yaml --img 640 --epochs 300
# # See tutorials for hyperparameter evolution https://github.com/ultralytics/yolov5#tutorials
#
# lr0: 0.01  # initial learning rate (SGD=1E-2, Adam=1E-3)
# lrf: 0.1  # final OneCycleLR learning rate (lr0 * lrf)
# momentum: 0.937  # SGD momentum/Adam beta1
# weight_decay: 0.0005  # optimizer weight decay 5e-4
# warmup_epochs: 3.0  # warmup epochs (fractions ok)
# warmup_momentum: 0.8  # warmup initial momentum
# warmup_bias_lr: 0.1  # warmup initial bias lr
# box: 0.05  # box loss gain
# cls: 0.5  # cls loss gain
# cls_pw: 1.0  # cls BCELoss positive_weight
# obj: 1.0  # obj loss gain (scale with pixels)
# obj_pw: 1.0  # obj BCELoss positive_weight
# iou_t: 0.20  # IoU training threshold
# anchor_t: 4.0  # anchor-multiple threshold
# # anchors: 3  # anchors per output layer (0 to ignore)
# fl_gamma: 0.0  # focal loss gamma (efficientDet default gamma=1.5)
# hsv_h: 0.012  # image HSV-Hue augmentation (fraction)
# hsv_s: 0.6  # image HSV-Saturation augmentation (fraction)
# hsv_v: 0.3  # image HSV-Value augmentation (fraction)
# degrees: 2.0  # image rotation (+/- deg)
# translate: 0.3  # image translation (+/- fraction)
# scale: 0.25  # image scale (+/- gain)
# shear: 0.0  # image shear (+/- deg)
# perspective: 0.0  # image perspective (+/- fraction), range 0-0.001
# flipud: 0.1  # image flip up-down (probability)
# fliplr: 0.5  # image flip left-right (probability)
# mosaic: 0.7  # image mosaic (probability)
# mixup: 0.0  # image mixup (probability)
# copy_paste: 0.0  # segment copy-paste (probability)

# %% [markdown]
# A model trained with higher resolution images can have better results for detecting small objects

# %%
# !python "yolov5/train.py" --img 640 --hyp "yolov5/data/hyps/hyp.scratch.yaml" --batch 32 --epochs 30 --data "data.yaml" --weights "yolov5s.pt" --workers 23 --project "ben" --name "yolo_ben_30_I&L" --exist-ok

# %%
ls

# %%
# !python "yolov5/train.py" --img 640 --hyp "yolov5/data/hyps/hyp.scratch.yaml" --batch 20 --epochs 30 --data "data.yaml" --weights "yolov5s.pt" --workers 23 --project "ben" --name "yolo_ben_1" --exist-ok

# %%
# !python "yolov5/train.py" --img 640 --hyp "yolov5/data/hyps/hyp.scratch.yaml" --batch 64 --epochs 100 --data "data.yaml" --weights "yolov5s.pt" --workers 23 --project "ben" --name "yolo_ben_100" --exist-ok --device 0

# %%
# !python "yolov5/train.py" --img 640 --hyp "yolov5/data/hyps/hyp.scratch.yaml" --batch 32 --epochs 50 --data "data.yaml" --weights "yolov5s.pt" --workers 23 --project "ben" --name "yolo_ben_2" --exist-ok  --device 0

# %% [markdown]
# add smthg to device ; une des variables pas dans le GPU

# %%
# !python "yolov5/train.py" --img 640 --hyp "yolov5/data/hyps/hyp.scratch.yaml" --batch 32 --epochs 10 0 --data "data.yaml" --weights "yolov5s.pt" --workers 23 -
